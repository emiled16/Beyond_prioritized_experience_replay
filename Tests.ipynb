# %%
# !pip install colab_ssh --upgrade
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip install pyvirtualdisplay
# !pip install gym
from IPython.display import clear_output 
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared



from google.colab import drive
import os
drive.mount('/content/gdrive')
clear_output()
ssh_tunnel_password = "1111"
launch_ssh_cloudflared(password=ssh_tunnel_password)
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %%
# %cd /content/gdrive/MyDrive/project/
# !rm -r Beyond_prioritized_experience_replay
# !git https://github.com/emiled16/Beyond_prioritized_experience_replay.git
# %cd Beyond_prioritized_experience_replay
clear_output()

# %%
# !ls
# Out:
# agent2.py   cloudflared		  main2.py	 SegmentTree2.py
# agent3.py   cloudflared.log	  main3.py	 SegmentTree.py
# agent.py    final_agent.py	  main4.py	 SignAgent.py
# agentv.py   final_buffer.py	  mainHybrid.py  SuperBufer.py
# buffer2.py  final_main.py	  main.py	 videos
# buffer3.py  final_model.py	  mainv.py
# buffer.py   final_SegmentTree.py  model.py
# bufferv.py  hybridAgent.py	  __pycache__

# %%
env_list = ['Acrobot-v1','CartPole-v0','CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v0']

# %%
from final_main import run_experiment
env = env_list[0]
num_episodes = 200
memory_size = 10000
batch_size = 32
target_update = 100
epsilon_decay = 1 / 2000
alpha=0.2
beta = 0.6
prior_eps = 1e-6
staleness = 0
positive_reward = 0
differential = False
priority_based = 'priority'
episodic = False

# %% [markdown]
# # Testing different environment

# %%
from final_main import run_experiment
run_experiment(env_id=env, seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  -98.0
# videos/openaigym.video.1.10419.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
run_experiment(env_id=env_list[1], seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  112.0
# videos/openaigym.video.2.10419.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
run_experiment(env_id=env_list[2], seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  187.0
# videos/openaigym.video.3.10419.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
run_experiment(env_id=env_list[3], seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  -200.0
# videos/openaigym.video.0.86.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
run_experiment(env_id=env_list[4], seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)

# %%
run_experiment(env_id=env_list[5], seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)

# %% [markdown]
# # Testing the different priority methods (rank, priority, hybrid)

# %%
priority_based = 'priority'
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.0.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'rank'
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.1.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'hybrid'
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.0.2059.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %% [markdown]
# # Testing different memory sizes

# %%
priority_based = 'priority'
memory_size = 100
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  12.0
# videos/openaigym.video.2.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'priority'
memory_size = 1000
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  35.0
# videos/openaigym.video.3.11240.video000125.mp4
# score:  35.0
# videos/openaigym.video.3.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'priority'
memory_size = 10000
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.4.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %% [markdown]
# # Testing with and without staleness

# %% [markdown]
# ### Priority

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  112.0
# videos/openaigym.video.5.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0.1
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.6.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0.0001
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.7.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %% [markdown]
# ### Rank

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0.1
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  125.0
# videos/openaigym.video.9.11240.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0.0001
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)

# %% [markdown]
# # Testing with and without positive reward

# %% [markdown]
# ### Priority

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0
positive_reward = 0
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  33.0
# videos/openaigym.video.11.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0
positive_reward = 0.1
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.10.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0
positive_reward = 0.0001
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.8.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %% [markdown]
# ### Rank

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0
positive_reward = 0
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.0.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0
positive_reward = 0.1
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.1.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0
positive_reward = 0.0001
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.2.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %% [markdown]
# # Tetsing differential

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0
positive_reward = 0
differential = True
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.3.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0
positive_reward = 0
differential = True
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  19.0
# videos/openaigym.video.4.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %% [markdown]
# # Tetsing all

# %%
priority_based = 'priority'
memory_size = 10000
staleness = 0.0001
positive_reward = 0.0001
differential = False
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.5.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'rank'
memory_size = 10000
staleness = 0.0001
positive_reward = 0.0001
differential = False
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  200.0
# videos/openaigym.video.6.315.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>

# %%
priority_based = 'hybrid'
memory_size = 10000
staleness = 0
positive_reward = 0
differential = True
run_experiment(env_id='CartPole-v0', seed=777, num_episodes=num_episodes, memory_size=memory_size,
               batch_size=batch_size, target_update=target_update, epsilon_decay=epsilon_decay,
               alpha=alpha, beta=beta, prior_eps=prior_eps,
               staleness=staleness, positive_reward=positive_reward, differential=differential,
               priority_based=priority_based, episodic=episodic)
# Out:
# score:  15.0
# videos/openaigym.video.1.2059.video000125.mp4
#                 <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                 </video>
